# %% [markdown]
# <a href="https://colab.research.google.com/github/Yoshitha61/PP/blob/main/Datasets.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Datasets and their operations.

# %%
import pandas as pd
import numpy as np

# %%
data=pd.read_csv('/content/car-sales-extended-missing-data.csv')
data
# Out:
#        Make Colour  Odometer (KM)  Doors    Price
# 0     Honda  White        35431.0    4.0  15323.0
# 1       BMW   Blue       192714.0    5.0  19943.0
# 2     Honda  White        84714.0    4.0  28343.0
# 3    Toyota  White       154365.0    4.0  13434.0
# 4    Nissan   Blue       181577.0    3.0  14043.0
# ..      ...    ...            ...    ...      ...
# 995  Toyota  Black        35820.0    4.0  32042.0
# 996     NaN  White       155144.0    3.0   5716.0
# 997  Nissan   Blue        66604.0    4.0  31570.0
# 998   Honda  White       215883.0    4.0   4001.0
# 999  Toyota   Blue       248360.0    4.0  12732.0
#
# [1000 rows x 5 columns]

# %%
data.head(20)
# Out:
#       Make Colour  Odometer (KM)  Doors    Price
# 0    Honda  White        35431.0    4.0  15323.0
# 1      BMW   Blue       192714.0    5.0  19943.0
# 2    Honda  White        84714.0    4.0  28343.0
# 3   Toyota  White       154365.0    4.0  13434.0
# 4   Nissan   Blue       181577.0    3.0  14043.0
# 5    Honda    Red        42652.0    4.0  23883.0
# 6   Toyota   Blue       163453.0    4.0   8473.0
# 7    Honda  White            NaN    4.0  20306.0
# 8      NaN  White       130538.0    4.0   9374.0
# 9    Honda   Blue        51029.0    4.0  26683.0
# 10  Nissan  White       167421.0    4.0  16259.0
# 11  Nissan  Green        17119.0    4.0   6160.0
# 12  Nissan  White       102303.0    4.0  16909.0
# 13     NaN  White       134181.0    4.0  11121.0
# 14   Honda   Blue       199833.0    4.0  18946.0
# 15  Toyota   Blue       205592.0    4.0  16290.0
# 16  Toyota    Red        96742.0    4.0  34465.0
# 17     BMW  White       194189.0    5.0  17177.0
# ...

# %%
df=pd.DataFrame(data)
da=df
df.head(30)
# Out:
#       Make Colour  Odometer (KM)  Doors    Price
# 0    Honda  White        35431.0    4.0  15323.0
# 1      BMW   Blue       192714.0    5.0  19943.0
# 2    Honda  White        84714.0    4.0  28343.0
# 3   Toyota  White       154365.0    4.0  13434.0
# 4   Nissan   Blue       181577.0    3.0  14043.0
# 5    Honda    Red        42652.0    4.0  23883.0
# 6   Toyota   Blue       163453.0    4.0   8473.0
# 7    Honda  White            NaN    4.0  20306.0
# 8      NaN  White       130538.0    4.0   9374.0
# 9    Honda   Blue        51029.0    4.0  26683.0
# 10  Nissan  White       167421.0    4.0  16259.0
# 11  Nissan  Green        17119.0    4.0   6160.0
# 12  Nissan  White       102303.0    4.0  16909.0
# 13     NaN  White       134181.0    4.0  11121.0
# 14   Honda   Blue       199833.0    4.0  18946.0
# 15  Toyota   Blue       205592.0    4.0  16290.0
# 16  Toyota    Red        96742.0    4.0  34465.0
# 17     BMW  White       194189.0    5.0  17177.0
# ...

# %%
drop=df.dropna()
drop.head(30)
# Out:
#       Make Colour  Odometer (KM)  Doors    Price
# 0    Honda  White        35431.0    4.0  15323.0
# 1      BMW   Blue       192714.0    5.0  19943.0
# 2    Honda  White        84714.0    4.0  28343.0
# 3   Toyota  White       154365.0    4.0  13434.0
# 4   Nissan   Blue       181577.0    3.0  14043.0
# 5    Honda    Red        42652.0    4.0  23883.0
# 6   Toyota   Blue       163453.0    4.0   8473.0
# 9    Honda   Blue        51029.0    4.0  26683.0
# 10  Nissan  White       167421.0    4.0  16259.0
# 11  Nissan  Green        17119.0    4.0   6160.0
# 12  Nissan  White       102303.0    4.0  16909.0
# 14   Honda   Blue       199833.0    4.0  18946.0
# 15  Toyota   Blue       205592.0    4.0  16290.0
# 16  Toyota    Red        96742.0    4.0  34465.0
# 17     BMW  White       194189.0    5.0  17177.0
# 18  Nissan  White        67991.0    3.0   9109.0
# 19  Nissan   Blue       215820.0    4.0   6010.0
# 22  Toyota  White       148744.0    4.0  22489.0
# ...

# %%
df.dropna(inplace=True)
df.head(30)
# Out:
#       Make Colour  Odometer (KM)  Doors    Price
# 0    Honda  White        35431.0    4.0  15323.0
# 1      BMW   Blue       192714.0    5.0  19943.0
# 2    Honda  White        84714.0    4.0  28343.0
# 3   Toyota  White       154365.0    4.0  13434.0
# 4   Nissan   Blue       181577.0    3.0  14043.0
# 5    Honda    Red        42652.0    4.0  23883.0
# 6   Toyota   Blue       163453.0    4.0   8473.0
# 9    Honda   Blue        51029.0    4.0  26683.0
# 10  Nissan  White       167421.0    4.0  16259.0
# 11  Nissan  Green        17119.0    4.0   6160.0
# 12  Nissan  White       102303.0    4.0  16909.0
# 14   Honda   Blue       199833.0    4.0  18946.0
# 15  Toyota   Blue       205592.0    4.0  16290.0
# 16  Toyota    Red        96742.0    4.0  34465.0
# 17     BMW  White       194189.0    5.0  17177.0
# 18  Nissan  White        67991.0    3.0   9109.0
# 19  Nissan   Blue       215820.0    4.0   6010.0
# 22  Toyota  White       148744.0    4.0  22489.0
# ...

# %%
df['Price']
# Out:
# 0      15323.0
# 1      19943.0
# 2      28343.0
# 3      13434.0
# 4      14043.0
#         ...
# 994    31666.0
# 995    32042.0
# 997    31570.0
# 998     4001.0
# 999    12732.0
# Name: Price, Length: 773, dtype: float64

# %%
df['Price'].dropna()
# Out:
# 0      15323.0
# 1      19943.0
# 2      28343.0
# 3      13434.0
# 4      14043.0
#         ...
# 994    31666.0
# 995    32042.0
# 997    31570.0
# 998     4001.0
# 999    12732.0
# Name: Price, Length: 773, dtype: float64

# %%
df.loc[:,['Colour','Price']] //without nan values
# Out:
#     Colour    Price
# 0    White  15323.0
# 1     Blue  19943.0
# 2    White  28343.0
# 3    White  13434.0
# 4     Blue  14043.0
# ..     ...      ...
# 994   Blue  31666.0
# 995  Black  32042.0
# 997   Blue  31570.0
# 998  White   4001.0
# 999   Blue  12732.0
#
# [773 rows x 2 columns]

# %%
da.fillna('Missing')
da.head(20)
# Out:
#       Make Colour  Odometer (KM)  Doors    Price
# 0    Honda  White        35431.0    4.0  15323.0
# 1      BMW   Blue       192714.0    5.0  19943.0
# 2    Honda  White        84714.0    4.0  28343.0
# 3   Toyota  White       154365.0    4.0  13434.0
# 4   Nissan   Blue       181577.0    3.0  14043.0
# 5    Honda    Red        42652.0    4.0  23883.0
# 6   Toyota   Blue       163453.0    4.0   8473.0
# 7    Honda  White            NaN    4.0  20306.0
# 8      NaN  White       130538.0    4.0   9374.0
# 9    Honda   Blue        51029.0    4.0  26683.0
# 10  Nissan  White       167421.0    4.0  16259.0
# 11  Nissan  Green        17119.0    4.0   6160.0
# 12  Nissan  White       102303.0    4.0  16909.0
# 13     NaN  White       134181.0    4.0  11121.0
# 14   Honda   Blue       199833.0    4.0  18946.0
# 15  Toyota   Blue       205592.0    4.0  16290.0
# 16  Toyota    Red        96742.0    4.0  34465.0
# 17     BMW  White       194189.0    5.0  17177.0
# ...
